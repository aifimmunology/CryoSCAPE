# %%
import sys
import getopt
import shutil
import h5py
import pandas
import scanpy as sc
import scrublet
import re
import os

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       1_gnu    conda-forge
# absl-py                   1.0.0                    pypi_0    pypi
# aiohttp                   3.8.1            py37h5e8e339_0    conda-forge
# aiosignal                 1.2.0              pyhd8ed1ab_0    conda-forge
# anndata                   0.8.0                    pypi_0    pypi
# annoy                     1.17.3                   pypi_0    pypi
# ansi2html                 1.7.0                    pypi_0    pypi
# ansiwrap                  0.8.4                      py_0    conda-forge
# anyio                     3.4.0            py37h89c1867_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argcomplete               1.12.3             pyhd8ed1ab_2    conda-forge
# argon2-cffi               21.1.0           py37h5e8e339_2    conda-forge
# arrow                     1.2.1              pyhd8ed1ab_0    conda-forge
# asn1crypto                1.4.0              pyh9f0ad1d_0    conda-forge
# async-timeout             4.0.1              pyhd8ed1ab_0    conda-forge
# async_generator           1.10                       py_0    conda-forge
# asynctest                 0.13.0                     py_0    conda-forge
# attrs                     21.2.0             pyhd8ed1ab_0    conda-forge
# babel                     2.9.1              pyh44b312d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports-zoneinfo        0.2.1                    pypi_0    pypi
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# beatrix-jupyterlab        3.1.6                    pypi_0    pypi
# beautifulsoup4            4.10.0                   pypi_0    pypi
# binaryornot               0.4.4                      py_1    conda-forge
# biopython                 1.79                     pypi_0    pypi
# black                     21.12b0            pyhd8ed1ab_0    conda-forge
# bleach                    4.1.0              pyhd8ed1ab_0    conda-forge
# blinker                   1.4                        py_1    conda-forge
# bottleneck                1.3.2            py37hb1e94ed_5    conda-forge
# brotli                    1.0.9                    pypi_0    pypi
# brotli-bin                1.0.9                h7f98852_6    conda-forge
# brotlipy                  0.7.0           py37h27cfd23_1003
# c-ares                    1.18.1               h7f98852_0    conda-forge
# ca-certificates           2021.10.8            ha878542_0    conda-forge
# cached-property           1.5.2                    pypi_0    pypi
# cachetools                4.2.4              pyhd8ed1ab_0    conda-forge
# certifi                   2021.10.8        py37h89c1867_1    conda-forge
# cffi                      1.15.0           py37h036bc23_0    conda-forge
# chardet                   4.0.0           py37h06a4308_1003
# charset-normalizer        2.0.9              pyhd8ed1ab_0    conda-forge
# chex                      0.1.3                    pypi_0    pypi
# click                     8.0.3            py37h89c1867_1    conda-forge
# cloudpickle               2.0.0              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.4              pyh9f0ad1d_0    conda-forge
# colour                    0.1.5                    pypi_0    pypi
# commonmark                0.9.1                    pypi_0    pypi
# conda                     4.11.0           py37h89c1867_0    conda-forge
# conda-package-handling    1.7.3            py37h27cfd23_1
# confuse                   1.7.0              pyhd8ed1ab_0    conda-forge
# cookiecutter              1.7.0                      py_0    conda-forge
# cryptography              36.0.1           py37hf1a17b8_0    conda-forge
# cycler                    0.11.0             pyhd8ed1ab_0    conda-forge
# cython                    3.0.10                   pypi_0    pypi
# dash                      2.3.1                    pypi_0    pypi
# dash-bio                  1.0.1                    pypi_0    pypi
# dash-core-components      2.0.0                    pypi_0    pypi
# dash-html-components      2.0.0                    pypi_0    pypi
# dash-table                5.0.0                    pypi_0    pypi
# dataclasses               0.8                pyhc8e2a94_3    conda-forge
# debugpy                   1.5.1            py37hcd2ae1e_0    conda-forge
# decorator                 5.1.0              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# dlenv-base                1.0.20211218     py37hef38c82_0    file:///tmp/conda
# dm-tree                   0.1.7                    pypi_0    pypi
# docker-py                 5.0.3            py37h89c1867_2    conda-forge
# docker-pycreds            0.4.0                      py_0    conda-forge
# docrep                    0.3.2                    pypi_0    pypi
# entrypoints               0.3             pyhd8ed1ab_1003    conda-forge
# et-xmlfile                1.1.0                    pypi_0    pypi
# flask                     2.1.1                    pypi_0    pypi
# flask-compress            1.11                     pypi_0    pypi
# flatbuffers               2.0                      pypi_0    pypi
# flax                      0.4.1                    pypi_0    pypi
# fonttools                 4.28.4           py37h5e8e339_0    conda-forge
# freetype                  2.10.4               h0708190_1    conda-forge
# frozen-flask              0.18                     pypi_0    pypi
# frozenlist                1.2.0            py37h5e8e339_1    conda-forge
# fsspec                    2021.11.1          pyhd8ed1ab_0    conda-forge
# future                    0.18.2           py37h89c1867_4    conda-forge
# gcsfs                     2021.11.1          pyhd8ed1ab_0    conda-forge
# geoparse                  2.0.3                    pypi_0    pypi
# gitdb                     4.0.9              pyhd8ed1ab_0    conda-forge
# gitpython                 3.1.24             pyhd8ed1ab_0    conda-forge
# google                    3.0.0                    pypi_0    pypi
# google-api-core           2.3.2              pyhd8ed1ab_0    conda-forge
# google-api-core-grpcio-gcp 2.3.2                hd8ed1ab_0    conda-forge
# google-api-python-client  2.33.0             pyhd8ed1ab_0    conda-forge
# google-auth               2.3.3              pyh6c4a22f_0    conda-forge
# google-auth-httplib2      0.1.0              pyhd8ed1ab_0    conda-forge
# google-auth-oauthlib      0.4.6              pyhd8ed1ab_0    conda-forge
# google-cloud-aiplatform   1.8.1                    pypi_0    pypi
# google-cloud-appengine-logging 1.1.0                    pypi_0    pypi
# google-cloud-audit-log    0.2.0                    pypi_0    pypi
# google-cloud-bigquery     2.31.0                   pypi_0    pypi
# google-cloud-bigquery-storage 2.10.1                   pypi_0    pypi
# google-cloud-bigtable     2.4.0                    pypi_0    pypi
# google-cloud-core         2.2.1              pyh6c4a22f_0    conda-forge
# google-cloud-dataproc     3.1.1                    pypi_0    pypi
# google-cloud-datastore    2.4.0                    pypi_0    pypi
# google-cloud-firestore    2.3.4                    pypi_0    pypi
# google-cloud-kms          2.10.1                   pypi_0    pypi
# google-cloud-language     2.3.1                    pypi_0    pypi
# google-cloud-logging      2.7.0                    pypi_0    pypi
# google-cloud-monitoring   2.8.0                    pypi_0    pypi
# google-cloud-pubsub       1.7.0                    pypi_0    pypi
# google-cloud-scheduler    2.5.0                    pypi_0    pypi
# google-cloud-spanner      3.12.0                   pypi_0    pypi
# google-cloud-speech       2.11.1                   pypi_0    pypi
# google-cloud-storage      1.43.0             pyh6c4a22f_0    conda-forge
# google-cloud-tasks        2.7.1                    pypi_0    pypi
# google-cloud-translate    3.6.1                    pypi_0    pypi
# google-cloud-videointelligence 2.5.1                    pypi_0    pypi
# google-cloud-vision       2.6.3                    pypi_0    pypi
# google-crc32c             1.1.2            py37hab72019_2    conda-forge
# google-resumable-media    2.1.0              pyh6c4a22f_0    conda-forge
# googleapis-common-protos  1.53.0           py37h89c1867_1    conda-forge
# greenlet                  1.1.2            py37hcd2ae1e_1    conda-forge
# grpc-google-iam-v1        0.12.3                   pypi_0    pypi
# grpcio                    1.43.0                   pypi_0    pypi
# grpcio-gcp                0.2.2            py37h89c1867_5    conda-forge
# grpcio-status             1.43.0                   pypi_0    pypi
# h5py                      3.6.0                    pypi_0    pypi
# hisepy                    0.1.19                   pypi_0    pypi
# htmlmin                   0.1.12                     py_1    conda-forge
# httplib2                  0.20.2             pyhd8ed1ab_1    conda-forge
# icu                       68.2                 h9c3ff4c_0    conda-forge
# idna                      3.1                pyhd3deb0d_0    conda-forge
# igraph                    0.9.10                   pypi_0    pypi
# imagehash                 4.2.1              pyhd8ed1ab_0    conda-forge
# imageio                   2.31.2                   pypi_0    pypi
# importlib-metadata        4.9.0            py37h89c1867_0    conda-forge
# importlib_metadata        4.9.0                hd8ed1ab_0    conda-forge
# importlib_resources       5.4.0              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.6.0            py37h6531663_0    conda-forge
# ipython                   7.30.1           py37h89c1867_0    conda-forge
# ipython-sql               0.3.9           pyhd8ed1ab_1004    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                7.6.5              pyhd8ed1ab_0    conda-forge
# itsdangerous              2.1.2                    pypi_0    pypi
# jax                       0.3.7                    pypi_0    pypi
# jaxlib                    0.3.7                    pypi_0    pypi
# jbig                      2.1               h7f98852_2003    conda-forge
# jedi                      0.18.1           py37h89c1867_0    conda-forge
# jeepney                   0.7.1                    pypi_0    pypi
# jinja2                    3.0.3              pyhd8ed1ab_0    conda-forge
# jinja2-time               0.2.0                      py_2    conda-forge
# joblib                    1.0.1              pyhd8ed1ab_0    conda-forge
# jpeg                      9d                   h36c2ea0_0    conda-forge
# json5                     0.9.5              pyh9f0ad1d_0    conda-forge
# jsonschema                4.3.1              pyhd8ed1ab_0    conda-forge
# jupyter-dash              0.4.2                    pypi_0    pypi
# jupyter-http-over-ws      0.0.8                    pypi_0    pypi
# jupyter-server-mathjax    0.2.3              pyhd8ed1ab_0    conda-forge
# jupyter-server-proxy      3.2.0              pyhd8ed1ab_0    conda-forge
# jupyter_client            7.1.0              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.9.1            py37h89c1867_1    conda-forge
# jupyter_server            1.13.1             pyhd8ed1ab_0    conda-forge
# jupyterlab                3.2.5              pyhd8ed1ab_0    conda-forge
# jupyterlab-git            0.34.0             pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# jupyterlab_server         2.9.0              pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        1.0.2              pyhd8ed1ab_0    conda-forge
# jupytext                  1.13.4             pyh6002c4b_0    conda-forge
# kaleido                   0.2.1                    pypi_0    pypi
# keyring                   23.4.0                   pypi_0    pypi
# keyrings-google-artifactregistry-auth 1.0.0                    pypi_0    pypi
# kiwisolver                1.3.2            py37h2527ec5_1    conda-forge
# lcms2                     2.12                 hddcbb42_0    conda-forge
# ld_impl_linux-64          2.36.1               hea4e1c9_2    conda-forge
# leidenalg                 0.8.10                   pypi_0    pypi
# lerc                      3.0                  h9c3ff4c_0    conda-forge
# libblas                   3.9.0           12_linux64_openblas    conda-forge
# libbrotlicommon           1.0.9                h7f98852_6    conda-forge
# libbrotlidec              1.0.9                h7f98852_6    conda-forge
# libbrotlienc              1.0.9                h7f98852_6    conda-forge
# libcblas                  3.9.0           12_linux64_openblas    conda-forge
# libcrc32c                 1.1.2                h9c3ff4c_0    conda-forge
# libcst                    0.3.23                   pypi_0    pypi
# libdeflate                1.8                  h7f98852_0    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc-ng                 11.2.0              h1d223b6_11    conda-forge
# libgfortran-ng            11.2.0              h69a702a_11    conda-forge
# libgfortran5              11.2.0              h5c6108e_11    conda-forge
# libgomp                   11.2.0              h1d223b6_11    conda-forge
# liblapack                 3.9.0           12_linux64_openblas    conda-forge
# libllvm11                 11.1.0               hf817b99_2    conda-forge
# libnsl                    2.0.0                h7f98852_0    conda-forge
# libopenblas               0.3.18          pthreads_h8fe5266_0    conda-forge
# libpng                    1.6.37               h21135ba_2    conda-forge
# libprotobuf               3.19.1               h780b84a_0    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libstdcxx-ng              11.2.0              he4da1e4_11    conda-forge
# libtiff                   4.3.0                h6f004c6_2    conda-forge
# libuv                     1.42.0               h7f98852_0    conda-forge
# libwebp-base              1.2.1                h7f98852_0    conda-forge
# libzlib                   1.2.11            h36c2ea0_1013    conda-forge
# llvmlite                  0.37.0           py37h9d7f4d0_1    conda-forge
# lz4-c                     1.9.3                h9c3ff4c_1    conda-forge
# macs2                     2.2.7.1                  pypi_0    pypi
# markdown                  3.3.6              pyhd8ed1ab_0    conda-forge
# markdown-it-py            1.1.0              pyhd8ed1ab_0    conda-forge
# markupsafe                2.0.1            py37h5e8e339_1    conda-forge
# matplotlib-base           3.5.1            py37h1058ff1_0    conda-forge
# matplotlib-inline         0.1.3              pyhd8ed1ab_0    conda-forge
# mdit-py-plugins           0.3.0              pyhd8ed1ab_0    conda-forge
# missingno                 0.4.2                      py_1    conda-forge
# mistune                   0.8.4           py37h5e8e339_1005    conda-forge
# msgpack                   1.0.3                    pypi_0    pypi
# multidict                 5.2.0            py37h5e8e339_1    conda-forge
# multimethod               1.4                        py_0    conda-forge
# multipledispatch          0.6.0                    pypi_0    pypi
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mypy_extensions           0.4.3            py37h89c1867_4    conda-forge
# natsort                   8.1.0                    pypi_0    pypi
# nb_conda                  2.2.1            py37h89c1867_4    conda-forge
# nb_conda_kernels          2.3.1            py37h89c1867_1    conda-forge
# nbclassic                 0.3.4              pyhd8ed1ab_0    conda-forge
# nbclient                  0.5.9              pyhd8ed1ab_0    conda-forge
# nbconvert                 6.3.0            py37h89c1867_1    conda-forge
# nbdime                    3.1.1              pyhd8ed1ab_0    conda-forge
# nbformat                  5.1.3              pyhd8ed1ab_0    conda-forge
# ncurses                   6.2                  he6710b0_1
# nest-asyncio              1.5.4              pyhd8ed1ab_0    conda-forge
# networkx                  2.6.3              pyhd8ed1ab_1    conda-forge
# nodejs                    12.22.6              h8b53aa1_0    conda-forge
# notebook                  6.4.6              pyha770c72_0    conda-forge
# notebook-executor         0.2                      pypi_0    pypi
# numba                     0.54.1           py37h2d894fd_0    conda-forge
# numpy                     1.19.5           py37h038b26d_2    conda-forge
# numpyro                   0.9.2                    pypi_0    pypi
# oauthlib                  3.1.1              pyhd8ed1ab_0    conda-forge
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# opencv-python-headless    4.10.0.82                pypi_0    pypi
# openjpeg                  2.4.0                hb52868f_1    conda-forge
# openpyxl                  3.0.9                    pypi_0    pypi
# openssl                   1.1.1l               h7f98852_0    conda-forge
# opt-einsum                3.3.0                    pypi_0    pypi
# optax                     0.1.2                    pypi_0    pypi
# packaging                 21.3               pyhd8ed1ab_0    conda-forge
# pandas                    1.3.5            py37he8f5f7f_0    conda-forge
# pandas-profiling          3.1.0              pyhd8ed1ab_0    conda-forge
# pandoc                    2.16.2               h7f98852_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# papermill                 2.3.3              pyhd8ed1ab_1    conda-forge
# parmed                    3.4.3                    pypi_0    pypi
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# pathspec                  0.9.0              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.2              pyhd8ed1ab_0    conda-forge
# pep517                    0.12.0                   pypi_0    pypi
# periodictable             1.6.0                    pypi_0    pypi
# pexpect                   4.8.0              pyh9f0ad1d_2    conda-forge
# phik                      0.12.0           py37h18a2d16_1    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    8.4.0            py37h0f21c89_0    conda-forge
# pip                       22.1b1                   pypi_0    pypi
# pip-tools                 6.6.0                    pypi_0    pypi
# pipreqs                   0.4.11                   pypi_0    pypi
# platformdirs              2.3.0              pyhd8ed1ab_0    conda-forge
# plotly                    5.6.0                    pypi_0    pypi
# poyo                      0.5.0                      py_0    conda-forge
# prettytable               2.4.0              pyhd8ed1ab_0    conda-forge
# prometheus_client         0.12.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.24             pyha770c72_0    conda-forge
# proto-plus                1.19.8                   pypi_0    pypi
# protobuf                  3.19.1           py37hcd2ae1e_1    conda-forge
# psutil                    5.8.0                    pypi_0    pypi
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pyarrow                   6.0.1                    pypi_0    pypi
# pyasn1                    0.4.8                      py_0    conda-forge
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pybind11-abi              4                    hd8ed1ab_3    conda-forge
# pycosat                   0.6.3            py37h27cfd23_0
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pydantic                  1.8.2            py37h5e8e339_2    conda-forge
# pydeprecate               0.3.1                    pypi_0    pypi
# pygments                  2.10.0             pyhd8ed1ab_0    conda-forge
# pyjwt                     2.3.0              pyhd8ed1ab_1    conda-forge
# pynndescent               0.5.6                    pypi_0    pypi
# pyopenssl                 21.0.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.6              pyhd8ed1ab_0    conda-forge
# pyro-api                  0.1.2                    pypi_0    pypi
# pyro-ppl                  1.8.1                    pypi_0    pypi
# pyrsistent                0.18.0           py37h5e8e339_0    conda-forge
# pysocks                   1.7.1                    py37_1
# python                    3.7.12          hb7a2778_100_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-kubernetes         21.7.0             pyhd8ed1ab_0    conda-forge
# python-slugify            5.0.2              pyhd8ed1ab_0    conda-forge
# python_abi                3.7                     2_cp37m    conda-forge
# pytorch-lightning         1.5.10                   pypi_0    pypi
# pytz                      2021.3             pyhd8ed1ab_0    conda-forge
# pytz-deprecation-shim     0.1.0.post0              pypi_0    pypi
# pyu2f                     0.1.5              pyhd8ed1ab_0    conda-forge
# pywavelets                1.2.0            py37hb1e94ed_1    conda-forge
# pyyaml                    6.0              py37h5e8e339_3    conda-forge
# pyzmq                     22.3.0           py37h336d617_1    conda-forge
# readline                  8.1                  h27cfd23_0
# requests                  2.26.0             pyhd8ed1ab_1    conda-forge
# requests-oauthlib         1.3.0              pyh9f0ad1d_0    conda-forge
# retrying                  1.3.3                    pypi_0    pypi
# rich                      12.3.0                   pypi_0    pypi
# rpy2                      3.4.5                    pypi_0    pypi
# rsa                       4.8                pyhd8ed1ab_0    conda-forge
# ruamel_yaml               0.15.100         py37h27cfd23_0
# scanpy                    1.9.1                    pypi_0    pypi
# scikit-image              0.19.3                   pypi_0    pypi
# scikit-learn              1.0.1            py37hf9e9bfc_3    conda-forge
# scipy                     1.7.3            py37hf2a6cf1_0    conda-forge
# scrublet                  0.2.3                    pypi_0    pypi
# scvi-tools                0.16.1                   pypi_0    pypi
# seaborn                   0.11.2               hd8ed1ab_0    conda-forge
# seaborn-base              0.11.2             pyhd8ed1ab_0    conda-forge
# secretstorage             3.3.1                    pypi_0    pypi
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# session-info              1.0.0                    pypi_0    pypi
# setuptools                59.5.0                   pypi_0    pypi
# simpervisor               0.4                pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyhd3eb1b0_0
# smmap                     3.0.5              pyh44b312d_0    conda-forge
# sniffio                   1.2.0            py37h89c1867_2    conda-forge
# soupsieve                 2.3.1                    pypi_0    pypi
# sqlalchemy                1.4.28           py37h5e8e339_0    conda-forge
# sqlite                    3.37.0               h9cd32fc_0    conda-forge
# sqlparse                  0.4.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.13.1           py37hb1e94ed_0    conda-forge
# stdlib-list               0.8.0                    pypi_0    pypi
# tangled-up-in-unicode     0.1.0              pyhd8ed1ab_0    conda-forge
# tenacity                  8.0.1              pyhd8ed1ab_0    conda-forge
# tensorboard               2.8.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# terminado                 0.12.1           py37h89c1867_1    conda-forge
# testpath                  0.5.0              pyhd8ed1ab_0    conda-forge
# text-unidecode            1.3                        py_0    conda-forge
# texttable                 1.6.4                    pypi_0    pypi
# textwrap3                 0.9.2                      py_0    conda-forge
# threadpoolctl             3.0.0              pyh8a188c0_0    conda-forge
# tifffile                  2021.11.2                pypi_0    pypi
# tk                        8.6.11               h27826a3_1    conda-forge
# toml                      0.10.2             pyhd8ed1ab_0    conda-forge
# tomli                     1.2.2              pyhd8ed1ab_0    conda-forge
# toolz                     0.11.2                   pypi_0    pypi
# torch                     1.11.0                   pypi_0    pypi
# torchmetrics              0.8.1                    pypi_0    pypi
# tornado                   6.1              py37h5e8e339_2    conda-forge
# tqdm                      4.62.3             pyhd8ed1ab_0    conda-forge
# traitlets                 5.1.1              pyhd8ed1ab_0    conda-forge
# typed-ast                 1.5.1            py37h5e8e339_0    conda-forge
# typing-extensions         4.0.1                hd8ed1ab_0    conda-forge
# typing-inspect            0.7.1                    pypi_0    pypi
# typing_extensions         4.0.1              pyha770c72_0    conda-forge
# tzdata                    2021.5                   pypi_0    pypi
# tzlocal                   4.1                      pypi_0    pypi
# ujson                     5.0.0            py37hcd2ae1e_0    conda-forge
# umap-learn                0.5.3                    pypi_0    pypi
# unicodedata2              13.0.0.post2     py37h5e8e339_4    conda-forge
# unidecode                 1.3.2              pyhd8ed1ab_0    conda-forge
# uritemplate               4.1.1              pyhd8ed1ab_0    conda-forge
# urllib3                   1.26.7             pyhd8ed1ab_0    conda-forge
# visions                   0.7.4              pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# websocket-client          1.2.3              pyhd8ed1ab_0    conda-forge
# werkzeug                  2.1.1                    pypi_0    pypi
# wheel                     0.37.1                   pypi_0    pypi
# whichcraft                0.6.1                      py_0    conda-forge
# widgetsnbextension        3.5.2            py37h89c1867_1    conda-forge
# wrapt                     1.13.3           py37h5e8e339_1    conda-forge
# xarray                    0.20.2                   pypi_0    pypi
# xz                        5.2.5                h7b6447c_0
# yaml                      0.2.5                h7b6447c_0
# yarg                      0.1.9                    pypi_0    pypi
# yarl                      1.7.2            py37h5e8e339_1    conda-forge
# zeromq                    4.3.4                h9c3ff4c_1    conda-forge
# zipp                      3.6.0              pyhd8ed1ab_0    conda-forge
# zlib                      1.2.11            h36c2ea0_1013    conda-forge
# zstd                      1.5.0                ha95c52a_0    conda-forge

# %%
path = '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/'
paths = [path+i for i in os.listdir(path) if i[0] != '.']
paths
# Out:
# ['/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/PB05402_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/BL05401_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/PB05113_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/PB05401_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/PB05111_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/BL05113_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/BL05111_sample_filtered_feature_bc_matrix.h5',
#  '/home/jupyter/CS15_WHBL/CWB_Paper/01_Final_Data/01_Data/scrublet/BL05402_sample_filtered_feature_bc_matrix.h5']

# %%
# for i in paths:
def scrubby(x):
    name = x.split('/')[-1].split('_sample')[0]
    
    if x.split('.')[1] == 'h5':
        adata = sc.read_10x_h5(x)
        
        scrub = scrublet.Scrublet(adata.X)
        doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose=False)

        df = adata.obs
        df['Doublet_Score'] = doublet_scores
        df['Predicted_Doublet'] = predicted_doublets


        df.to_csv(path+name+'_2.csv')
    # return(df_merge)

# %%
for i in paths: scrubby(i)
# Out:
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
